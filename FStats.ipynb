# %% [markdown]
# <a href="https://colab.research.google.com/github/shanksghub/firstrepo/blob/master/FStats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from IPython.display import display, Markdown

from sklearn.linear_model import LinearRegression
url = 'https://raw.githubusercontent.com/shanksghub/FootballStats/master/FootballStats.csv'
df1 = pd.read_csv(url)
print(f"The columns are {list(df1.columns)}")
print(df1.head())


# Functional Approach for Regression Modeling
def regFunction(df, a,b, position):
    X = np.array(df[a]).reshape(-1,1)
    Y = np.array(df[b]).reshape(-1,1)
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=4)
    reg = LinearRegression()
    reg.fit(X_train, Y_train)
    Y_pred = reg.predict(X_test)
    r_square = r2_score(Y_pred, Y_test)
    mse = mean_squared_error(Y_pred, Y_test)
    display(Markdown(f"$ r^2 = {r_square*100}% $"))
    display(Markdown("$\\frac{1}{n}\\sum_{i=1}^{n}(\hat{y} - y)^2$" + f"= {mse}"))
    # visualization
    plt.figure(figsize=(8,8))
    plt.scatter(X_test, Y_test)
    plt.plot(X_test, Y_pred)
    plt.title(f"Regression between {a} and {b}", size=30)
    plt.xlabel(a, size=15)
    plt.ylabel(b, size=15)
    plt.show()
    plt.savefig(f"reg_{a}_{b}_{position}.png")
   
    # Reg Frame
    reg_dict = {f'test_{a}': X_test[-1], f'test_{b}': Y_test[-1], f'pred_{b}': Y_pred[-1]}
    regFrame = pd.DataFrame.from_dict(reg_dict)
    return regFrame

forwardFrame = df1.loc[df1['position'] == 'Forward']
forwardFrame.head()

print(regFunction(forwardFrame, 'appearances', 'goals', 'Forward'))
# Out:
# The columns are ['name', 'position', 'appearances', 'goals', 'tackles', 'passes', 'assists', 'shots', 'hit woordwork', 'crosses', 'blocks', 'clearances', 'headed clearances', 'clean sheets', 'saves', 'punches', 'goals conceded', 'yellow cards', 'red cards', 'fouls', 'offsides']
#                         name  position  appearances  goals  tackles  passes  \
# 0              Sergio Agüero   Forward           23     17       16   538.0
# 1            Aymeric Laporte  Defender           27      2       30  2313.0
# 2              Mohamed Salah   Forward           26     17       13   739.0
# 3  Pierre-Emerick Aubameyang   Forward           25     15       19   518.0
# 4                 Harry Kane   Forward           22     14        7   446.0
#
#    assists  shots  hit woordwork  crosses    ...     clearances  \
# 0        6     84              5        7    ...              3
# 1        1      0              0        6    ...             12
# 2        7     87              1       49    ...              4
# 3        4     63              3       26    ...             15
# 4        4     77              1        9    ...             11
#
#    headed clearances  clean sheets  saves  punches  goals conceded  \
# 0                  0             0      0        0               3
# 1                  0             0      0        3               0
# 2                  1             0      0        0               0
# 3                  4             0      0        0               0
# 4                  9             0      0        0               0
#
#    yellow cards  red cards  fouls  offsides
# 0           0.0       15.0   18.0       0.0
# 1          19.0        2.0    0.0       0.0
# 2           0.0        0.0   20.0      21.0
# 3           0.0        0.0   11.0      17.0
# 4           4.0        0.0   23.0       7.0
#
# [5 rows x 21 columns]
# $ r^2 = -1160441.666666675% $
# $\frac{1}{n}\sum_{i=1}^{n}(\hat{y} - y)^2$= 14.3866324615623
#    test_appearances  test_goals  pred_goals
# 0                24          12   11.481328

# %%
# Functional Approach for Regression Modeling
def regFunction(df, a,b, position):
    X = np.array(df[a]).reshape(-1,1)
    Y = np.array(df[b]).reshape(-1,1)
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=4)
    reg = LinearRegression()
    reg.fit(X_train, Y_train)
    Y_pred = reg.predict(X_test)
    r_square = r2_score(Y_pred, Y_test)
    mse = mean_squared_error(Y_pred, Y_test)
    display(Markdown(f"$ r^2 = {r_square*100}% $"))
    display(Markdown("$\\frac{1}{n}\\sum_{i=1}^{n}(\hat{y} - y)^2$" + f"= {mse}"))
    # visualization
    plt.figure(figsize=(12,8))
    plt.scatter(X_test, Y_test)
    plt.plot(X_test, Y_pred)
    plt.title(f"Regression between {a} and {b}", size=30)
    plt.xlabel(a, size=15)
    plt.ylabel(b, size=15)
    plt.show()
    plt.savefig(f"reg_{a}_{b}_{position}.png")
    # Reg Frame
    reg_dict = {f'test_{a}': X_test[-1], f'test_{b}': Y_test[-1], f'pred_{b}': Y_pred[-1]}
    regFrame = pd.DataFrame.from_dict(reg_dict)
    return regFrame

forwardFrame = df1.loc[df1['position'] == 'Forward']
forwardFrame.head()

print(regFunction(forwardFrame, 'passes', 'tackles', 'Forward'))
# Out:
# $ r^2 = -6173.946780739041% $
# $\frac{1}{n}\sum_{i=1}^{n}(\hat{y} - y)^2$= 9.058519861005186
#    test_passes  test_tackles  pred_tackles
# 0        920.0            22     18.044161

# %%
# Functional Approach for Regression Modeling
def regFunction(df, a,b, position):
    X = np.array(df[a]).reshape(-1,1)
    Y = np.array(df[b]).reshape(-1,1)
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=4)
    reg = LinearRegression()
    reg.fit(X_train, Y_train)
    Y_pred = reg.predict(X_test)
    r_square = r2_score(Y_pred, Y_test)
    mse = mean_squared_error(Y_pred, Y_test)
    display(Markdown(f"$ r^2 = {r_square*100}% $"))
    display(Markdown("$\\frac{1}{n}\\sum_{i=1}^{n}(\hat{y} - y)^2$" + f"= {mse}"))
    # visualization
    plt.figure(figsize=(12,8))
    plt.scatter(X_test, Y_test)
    plt.plot(X_test, Y_pred)
    plt.title(f"Regression between {a} and {b}", size=30)
    plt.xlabel(a, size=15)
    plt.ylabel(b, size=15)
    plt.show()
    plt.savefig(f"reg_{a}_{b}_{position}.png")
    # Reg Frame
    reg_dict = {f'test_{a}': X_test[-1], f'test_{b}': Y_test[-1], f'pred_{b}': Y_pred[-1]}
    regFrame = pd.DataFrame.from_dict(reg_dict)
    return regFrame

forwardFrame = df1.loc[df1['position'] == 'Forward']
forwardFrame.head()

print(regFunction(forwardFrame, 'passes', 'tackles', 'Forward'))
# Out:
# $ r^2 = -6173.946780739041% $
# $\frac{1}{n}\sum_{i=1}^{n}(\hat{y} - y)^2$= 9.058519861005186
#    test_passes  test_tackles  pred_tackles
# 0        920.0            22     18.044161

# %%
# Functional Approach for Regression Modeling
def regFunction(df, a,b, position):
    X = np.array(df[a]).reshape(-1,1)
    Y = np.array(df[b]).reshape(-1,1)
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=4)
    reg = LinearRegression()
    reg.fit(X_train, Y_train)
    Y_pred = reg.predict(X_test)
    r_square = r2_score(Y_pred, Y_test)
    mse = mean_squared_error(Y_pred, Y_test)
    display(Markdown(f"$ r^2 = {r_square*100}% $"))
    display(Markdown("$\\frac{1}{n}\\sum_{i=1}^{n}(\hat{y} - y)^2$" + f"= {mse}"))
    # visualization
    plt.figure(figsize=(12,8))
    plt.scatter(X_test, Y_test)
    plt.plot(X_test, Y_pred)
    plt.title(f"Regression between {a} and {b}", size=30)
    plt.xlabel(a, size=15)
    plt.ylabel(b, size=15)
    plt.show()
    plt.savefig(f"reg_{a}_{b}_{position}.png")
    # Reg Frame
    reg_dict = {f'test_{a}': X_test[-1], f'test_{b}': Y_test[-1], f'pred_{b}': Y_pred[-1]}
    regFrame = pd.DataFrame.from_dict(reg_dict)
    return regFrame

forwardFrame = df1.loc[df1['position'] == 'Forward']
forwardFrame.head()

print(regFunction(forwardFrame, 'shots', 'tackles', 'Forward'))
# Out:
# $ r^2 = 67.27619155037628% $
# $\frac{1}{n}\sum_{i=1}^{n}(\hat{y} - y)^2$= 3.3812178076162103
#    test_shots  test_tackles  pred_tackles
# 0           3            22     23.858324

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ffa8dcfbac57> in <module>()
# ----> 1 plt.xlabel('True values')
#
# NameError: name 'plt' is not defined
# Text(0.5, 0, 'True values')
